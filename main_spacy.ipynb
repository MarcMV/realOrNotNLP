# %% [markdown]
# # Real or Not real
#
# Predict which disaster tweet is real or not

# %%
import pandas as pd
import os
import spacy
from spacy.util import minibatch, compounding
import random

pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 1000)

# %% [markdown]
# ## Utility Functions

# %%
# Evaluates model and return F1 score.
def evaluate(tokenizer, textcat, texts, cats):
    docs = (tokenizer(text) for text in texts)
    tp = 0.0  # True positives
    fp = 1e-8  # False positives
    fn = 1e-8  # False negatives
    tn = 0.0  # True negatives
    for i, doc in enumerate(textcat.pipe(docs)):
        gold = cats[i]
        for label, score in doc.cats.items():
            if label not in gold:
                continue
            if label == "NEGATIVE":
                continue
            if score >= 0.5 and gold[label] >= 0.5:
                tp += 1.0
            elif score >= 0.5 and gold[label] < 0.5:
                fp += 1.0
            elif score < 0.5 and gold[label] < 0.5:
                tn += 1
            elif score < 0.5 and gold[label] >= 0.5:
                fn += 1
    precision = tp / (tp + fp)
    recall = tp / (tp + fn)
    if (precision + recall) == 0:
        f_score = 0.0
    else:
        f_score = 2 * (precision * recall) / (precision + recall)
    return {"textcat_p": precision, "textcat_r": recall, "textcat_f": f_score}

# Prep dataset and split in a train and test set
def prep_data(df_train,split=0.7):
    # Create tuple of values instead of dataframe
    subset =df_train[['text','target']]
    train_data = [tuple(x) for x in subset.to_numpy()]
    
    # Shuffle Data
    random.shuffle(train_data)
    
    # Seperate text and label
    texts, labels = zip(*train_data)
    cats = [{"POSITIVE": bool(y), "NEGATIVE": not bool(y)} for y in labels]
    
    # 70%-30% Train-test split
    split = int(len(train_data) * split)
    return (texts[:split], cats[:split]), (texts[split:], cats[split:])

# %% [markdown]
# ## Load Data and model

# %%
nlp = spacy.load('en_core_web_lg')

# %%
# Read tweets
df_train = pd.read_csv('train.csv')

# %%
print('Total number of rows in train set:' + str(df_train.shape[0]))
df_train.head()
# Out:
# Total number of rows in train set:7613
#    id keyword location                                               text  \
# 0   1     NaN      NaN  Our Deeds are the Reason of this #earthquake M...
# 1   4     NaN      NaN             Forest fire near La Ronge Sask. Canada
# 2   5     NaN      NaN  All residents asked to 'shelter in place' are ...
# 3   6     NaN      NaN  13,000 people receive #wildfires evacuation or...
# 4   7     NaN      NaN  Just got sent this photo from Ruby #Alaska as ...
#
#    target
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1

# %%
df_train.target.value_counts()
# Out:
# 0    4342
# 1    3271
# Name: target, dtype: int64

# %% [markdown]
# ## Classification with Spacy TextCategorizer

# %%
# add the text classifier to the pipeline if it doesn't exist
# nlp.create_pipe works for built-ins that are registered with spaCy
if "textcat" not in nlp.pipe_names:
    textcat = nlp.create_pipe(
        "textcat", config={"exclusive_classes": True, "architecture": "simple_cnn"}
    )
    nlp.add_pipe(textcat, last=True)
# otherwise, get it, so we can add labels to it
else:
    textcat = nlp.get_pipe("textcat")

# %%
# add label to text classifier
textcat.add_label("POSITIVE")
textcat.add_label("NEGATIVE")
# Out:
# 1

# %%
 # load the IMDB dataset
print("Loading Tweets...")
(train_texts, train_cats), (dev_texts, dev_cats) = prep_data(df_train)
# Out:
# Loading Tweets...

# %%
train_data = list(zip(train_texts, [{"cats": cats} for cats in train_cats]))

# %%
init_tok2vec = None

# %%
# get names of other pipes to disable them during training
pipe_exceptions = ["textcat", "trf_wordpiecer", "trf_tok2vec"]
other_pipes = [pipe for pipe in nlp.pipe_names if pipe not in pipe_exceptions]
with nlp.disable_pipes(*other_pipes):  # only train textcat
    optimizer = nlp.begin_training()
    if init_tok2vec is not None:
        with init_tok2vec.open("rb") as file_:
            textcat.model.tok2vec.from_bytes(file_.read())
    print("Training the model...")
    print("{:^5}\t{:^5}\t{:^5}\t{:^5}".format("LOSS", "P", "R", "F"))
    batch_sizes = compounding(4.0, 32.0, 1.001)
    for i in range(100):
        losses = {}
        # batch up the examples using spaCy's minibatch
        random.shuffle(train_data)
        batches = minibatch(train_data, size=batch_sizes)
        for batch in batches:
            texts, annotations = zip(*batch)
            nlp.update(texts, annotations, sgd=optimizer, drop=0.2, losses=losses)
        with textcat.model.use_params(optimizer.averages):
            # evaluate on the dev data split off in load_data()
            scores = evaluate(nlp.tokenizer, textcat, dev_texts, dev_cats)
        print(
            "{0:.3f}\t{1:.3f}\t{2:.3f}\t{3:.3f}".format(  # print a simple table
                losses["textcat"],
                scores["textcat_p"],
                scores["textcat_r"],
                scores["textcat_f"],
            )
        )
# Out:
# Training the model...
# LOSS 	  P  	  R  	  F
# 10.853	0.803	0.732	0.766
# 0.845	0.800	0.749	0.774
# 0.188	0.781	0.745	0.762
# 0.058	0.773	0.755	0.764
# 0.026	0.769	0.761	0.765
# 0.012	0.753	0.755	0.754
# 0.008	0.750	0.752	0.751
# 0.008	0.742	0.748	0.745
# 0.006	0.737	0.744	0.740
# 0.006	0.742	0.733	0.738
# 0.004	0.735	0.741	0.738
# 0.004	0.738	0.737	0.738
# 0.004	0.743	0.738	0.741
# 0.003	0.735	0.738	0.737
# 0.004	0.729	0.733	0.731
# 0.003	0.730	0.732	0.731
# 0.003	0.732	0.732	0.732
# 0.003	0.729	0.726	0.727
# 0.002	0.726	0.722	0.724
# 0.003	0.725	0.713	0.719
# 0.002	0.730	0.717	0.723
# 0.002	0.731	0.712	0.721
# 0.003	0.735	0.720	0.727
# 0.004	0.740	0.723	0.731
# 0.003	0.734	0.724	0.729
# 0.002	0.736	0.724	0.730
# 0.002	0.732	0.722	0.727
# 0.002	0.730	0.719	0.724
# 0.002	0.733	0.717	0.725
# 0.003	0.734	0.715	0.725
# 0.003	0.738	0.717	0.727
# 0.002	0.741	0.720	0.730
# 0.002	0.738	0.719	0.728
# 0.002	0.736	0.723	0.729
# 0.002	0.732	0.725	0.728
# 0.002	0.732	0.715	0.724
# 0.002	0.735	0.714	0.725
# 0.002	0.736	0.713	0.725
# 0.002	0.732	0.713	0.723
# 0.002	0.733	0.708	0.720
# 0.002	0.737	0.710	0.723
# 0.002	0.735	0.710	0.723
# 0.002	0.731	0.709	0.720
# 0.002	0.728	0.710	0.719
# 0.002	0.725	0.715	0.720
# 0.002	0.724	0.715	0.720
# 0.002	0.719	0.719	0.719
# 0.002	0.726	0.717	0.721
# 0.002	0.730	0.722	0.726
# 0.002	0.733	0.714	0.723
# 0.002	0.736	0.717	0.726
# 0.002	0.732	0.715	0.724
# 0.002	0.735	0.718	0.726
# 0.002	0.737	0.719	0.728
# 0.001	0.738	0.718	0.728
# 0.001	0.740	0.719	0.729
# 0.001	0.740	0.720	0.730
# 0.001	0.739	0.719	0.728
# 0.001	0.738	0.712	0.725
# 0.001	0.739	0.714	0.727
# 0.001	0.737	0.714	0.725
# 0.002	0.735	0.719	0.727
# 0.002	0.738	0.719	0.728
# 0.002	0.742	0.723	0.732
# 0.001	0.739	0.724	0.731
# 0.001	0.734	0.726	0.730
# 0.001	0.731	0.725	0.728
# 0.002	0.728	0.724	0.726
# 0.002	0.727	0.724	0.725
# 0.002	0.726	0.724	0.725
# 0.002	0.722	0.725	0.723
# 0.001	0.723	0.725	0.724
# 0.001	0.723	0.723	0.723
# 0.001	0.727	0.721	0.724
# 0.001	0.726	0.723	0.724
# 0.001	0.726	0.720	0.723
# 0.001	0.727	0.721	0.724
# 0.001	0.729	0.723	0.726
# 0.001	0.731	0.725	0.728
# 0.001	0.732	0.724	0.728
# 0.001	0.737	0.721	0.729
# 0.001	0.738	0.721	0.729
# 0.001	0.738	0.725	0.731
# 0.001	0.739	0.721	0.730
# 0.002	0.740	0.723	0.731
# 0.002	0.737	0.720	0.728
# 0.001	0.735	0.718	0.726
# 0.001	0.732	0.717	0.724
# 0.001	0.731	0.715	0.723
# 0.001	0.726	0.712	0.719
# 0.002	0.721	0.709	0.715
# 0.002	0.719	0.708	0.713
# 0.001	0.723	0.708	0.716
# 0.001	0.724	0.709	0.717
# 0.001	0.725	0.709	0.717
# 0.001	0.726	0.710	0.718
# 0.001	0.728	0.710	0.719
# 0.001	0.728	0.710	0.719
# 0.002	0.726	0.710	0.718
# 0.001	0.727	0.709	0.718

# %%
with nlp.use_params(optimizer.averages):
    nlp.to_disk('first_model')

# %% [markdown]
# ## Test the model

# %%
df_test = pd.read_csv('test.csv')

# %%
df_test.head()
# Out:
#    id keyword location                                               text
# 0   0     NaN      NaN                 Just happened a terrible car crash
# 1   2     NaN      NaN  Heard about #earthquake is different cities, s...
# 2   3     NaN      NaN  there is a forest fire at spot pond, geese are...
# 3   9     NaN      NaN           Apocalypse lighting. #Spokane #wildfires
# 4  11     NaN      NaN      Typhoon Soudelor kills 28 in China and Taiwan

# %%
# Tokenize text and use spacy model to make prediction
def calculate_target(text):
    doc = nlp(text)
    
    # Define predicted value
    pred = 0
    if doc.cats['POSITIVE']>0.5:
        pred =1
    
    return pred

# %%
df_test['target'] = df_test['text'].apply(lambda x: calculate_target(x))

# %%
df_test.head(100)
# Out:
#      id              keyword                        location  \
# 0     0                  NaN                             NaN
# 1     2                  NaN                             NaN
# 2     3                  NaN                             NaN
# 3     9                  NaN                             NaN
# 4    11                  NaN                             NaN
# 5    12                  NaN                             NaN
# 6    21                  NaN                             NaN
# 7    22                  NaN                             NaN
# 8    27                  NaN                             NaN
# 9    29                  NaN                             NaN
# 10   30                  NaN                             NaN
# 11   35                  NaN                             NaN
# 12   42                  NaN                             NaN
# 13   43                  NaN                             NaN
# 14   45                  NaN                             NaN
# 15   46               ablaze                          London
# 16   47               ablaze  Niall's place | SAF 12 SQUAD |
# 17   51               ablaze                         NIGERIA
# 18   58               ablaze                  Live On Webcam
# 19   60               ablaze        Los Angeles, Califnordia
# 20   69               ablaze                  threeonefive.
# 21   70               ablaze                Washington State
# 22   72               ablaze              Whoop Ass, Georgia
# 23   75               ablaze                           India
# 24   84               ablaze                             NaN
# 25   87               ablaze            scarborough, ontario
# 26   88               ablaze                             NaN
# 27   90               ablaze    121 N La Salle St, Suite 500
# 28   94               ablaze                       Wandering
# 29   99             accident                    Homewood, PA
# 30  101             accident                             NaN
# 31  103             accident                             NaN
# 32  106             accident                             USA
# 33  108             accident                   Massachusetts
# 34  111             accident                         Bexhill
# 35  115             accident                     Anime World
# 36  116             accident                             NaN
# 37  122             accident              Cowtown, Caliii !!
# 38  123             accident                             NaN
# 39  124             accident               All Motorways, UK
# 40  125             accident              Frankfurt, Germany
# 41  127             accident                     Gresham, OR
# 42  140             accident                             NaN
# 43  142             accident                      Las Vegas
# 44  147           aftershock                     Midland, Mi
# 45  148           aftershock        SÌ£o Vicente, SÌ£o Paulo
# 46  150           aftershock              Vault 101, Fallout
# 47  152           aftershock                     Switzerland
# 48  154           aftershock                      California
# 49  155           aftershock                          Europe
# 50  166           aftershock                             304
# 51  167           aftershock                       Davis, CA
# 52  169           aftershock                     Detroit, MI
# 53  177           aftershock                     Switzerland
# 54  179           aftershock                             NaN
# 55  181           aftershock                             304
# 56  186           aftershock                  United Kingdom
# 57  188           aftershock                 London, England
# 58  189           aftershock        In your hearts and minds
# 59  192           aftershock                         Runcorn
# 60  200  airplane%20accident                Lake Charles, LA
# 61  202  airplane%20accident                 California, USA
# 62  206  airplane%20accident                             NaN
# 63  207  airplane%20accident                             NaN
# 64  214  airplane%20accident               Eagle Pass, Texas
# 65  217  airplane%20accident                             NaN
# 66  223  airplane%20accident                inland empire ca
# 67  224  airplane%20accident                          Muscat
# 68  227  airplane%20accident                             NaN
# 69  228  airplane%20accident                        New York
# 70  230  airplane%20accident               #BlackLivesMatter
# 71  233  airplane%20accident      USA - Global Online Sales
# 72  234  airplane%20accident                             NaN
# 73  236  airplane%20accident                             NaN
# 74  239  airplane%20accident                          France
# 75  250            ambulance              Istanbul, TÌ_rkiye
# 76  255            ambulance         High in Prague with Aya
# 77  257            ambulance    Happily Married with 2 kids
# 78  259            ambulance           born on september 1st
# 79  275            ambulance                     Atlanta, GA
# 80  278            ambulance                            USA
# 81  282            ambulance                       Worldwide
# 82  284            ambulance                      everywhere
# 83  286            ambulance                           World
# 84  288            ambulance                             NaN
# 85  292            ambulance                West Chester, PA
# 86  295            ambulance         Chorley, Lancashire, UK
# 87  300          annihilated                             NaN
# 88  304          annihilated                       San Diego
# 89  305          annihilated                     New Orleans
# 90  306          annihilated         eileenborut,webster, tx
# 91  308          annihilated                             NaN
# 92  311          annihilated                             NaN
# 93  317          annihilated                             NaN
# 94  319          annihilated                             NaN
# 95  323          annihilated                             NaN
# 96  324          annihilated                             NaN
# 97  325          annihilated                      upstate NY
# 98  326          annihilated                             NaN
# 99  333          annihilated                             NaN
#
#                                                  text  target
# 0                  Just happened a terrible car crash       1
# 1   Heard about #earthquake is different cities, s...       1
# 2   there is a forest fire at spot pond, geese are...       1
# 3            Apocalypse lighting. #Spokane #wildfires       1
# 4       Typhoon Soudelor kills 28 in China and Taiwan       1
# 5                  We're shaking...It's an earthquake       0
# 6   They'd probably still show more life than Arse...       0
# 7                                   Hey! How are you?       0
# 8                                    What a nice hat?       0
# 9                                           Fuck off!       0
# 10                              No I don't like cold!       0
# 11                         NOOOOOOOOO! Don't do that!       0
# 12                             No don't tell me that!       0
# 13                                          What if?!       0
# 14                                           Awesome!       0
# 15  Birmingham Wholesale Market is ablaze BBC News...       1
# 16  @sunkxssedharry will you wear shorts for race ...       0
# 17  #PreviouslyOnDoyinTv: Toke MakinwaÛªs marriag...       1
# 18  Check these out: http://t.co/rOI2NSmEJJ http:/...       0
# 19  PSA: IÛªm splitting my personalities.\n\n?? t...       0
# 20       beware world ablaze sierra leone &amp; guap.       0
# 21  Burning Man Ablaze! by Turban Diva http://t.co...       0
# 22  Not a diss song. People will take 1 thing and ...       0
# 23  Rape victim dies as she sets herself ablaze: A...       1
# 24       SETTING MYSELF ABLAZE http://t.co/6vMe7P5XhC       0
# 25  @CTVToronto the bins in front of the field by ...       1
# 26  #nowplaying Alfons - Ablaze 2015 on Puls Radio...       0
# 27  'Burning Rahm': Let's hope City Hall builds a ...       0
# 28  @PhilippaEilhart @DhuBlath hurt but her eyes a...       0
# 29  Accident cleared in #PaTurnpike on PATP EB bet...       1
# 30  Just got to love burning your self on a damn c...       0
# 31                    I hate badging shit in accident       0
# 32  #3: Car Recorder ZeroEdgeå¨ Dual-lens Car Came...       1
# 33  Coincidence Or #Curse? Still #Unresolved Secre...       0
# 34  @Traffic_SouthE @roadpol_east Accident on A27 ...       1
# 35  @sakuma_en If you pretend to feel a certain wa...       0
# 36  For Legal and Medical Referral Service @1800_I...       1
# 37  There's a construction guy working on the Disn...       0
# 38  @RobynJilllian @WlSDOMTEETHS I feel like I'm g...       1
# 39  On the #M42 northbound between junctions J3 an...       1
# 40  @DaveOshry @Soembie So if I say that I met her...       0
# 41  ACCIDENT - HIT AND RUN - COLD at 500 BLOCK OF ...       1
# 42  @Calum5SOS this happened on accident but I lik...       1
# 43  Please donate and spread the word! A training ...       1
# 44  Please like and share our new page for our Ind...       0
# 45  @bxckylynch foi no ROH Aftershock: Las Vegas p...       0
# 46  Schoolboy ÛÒ Aftershock (Original Mix)\nExcis...       0
# 47  320 [IR] ICEMOON [AFTERSHOCK] | http://t.co/TH...       0
# 48  'When the aftershock happened (Nepal) we were ...       0
# 49  320 [IR] ICEMOON [AFTERSHOCK] | http://t.co/gR...       0
# 50  Stop saying 'I Wish' and start saying 'I Will'...       0
# 51  I want to go to Aftershock in October because ...       0
# 52  'We are still living in the aftershock of Hiro...       0
# 53  320 [IR] ICEMOON [AFTERSHOCK] | http://t.co/TH...       0
# 54                 Aftershock https://t.co/Ecy4U623nO       0
# 55  'There is no victory at bargain basement price...       0
# 56  Bo2 had by far the best competitive maps imo h...       0
# 57  Brass and Copper in Cataclysm &amp; AfterShock...       0
# 58  @JadeForMKX You should be happy I don't use Af...       0
# 59                 Aftershock https://t.co/38Nhq9moEf       0
# 60  When carelessness leads to an aviation acciden...       1
# 61  @rewind_music found out about you guys today(r...       1
# 62  A girl who died in an airplane accident fiftee...       1
# 63  @Mintechan Hihow are you? There is Keio line o...       1
# 64  Mexican airplane accident in Ocampo Coahuila M...       0
# 65  Horrible Accident  Man Died In Wings of Airpla...       1
# 66  @god if an accident were to happen on this air...       0
# 67  Horrible Accident Man Died In Wings of Airplan...       1
# 68  #UPDATE: Picture from the Penn Twp. airplane a...       1
# 69  See how a judge ruled in this 2009 accident at...       1
# 70  @thugIauren I had myself on airplane mode by a...       0
# 71  36 years ago today baseball lost one of its gr...       0
# 72  Experts in France begin examining airplane deb...       1
# 73  #BreakingNews Experts in France begin examinin...       1
# 74  Experts in France begin examining airplane deb...       1
# 75  Twelve feared killed in Pakistani air ambulanc...       1
# 76  http://t.co/Q5XTkaKM08 I'M DYING SEND AN AMBUL...       0
# 77  AMBULANCE SPRINTER AUTOMATIC FRONTLINE VEHICLE...       0
# 78  @disneyxrowbrina the ambulance isn't even park...       1
# 79  Shot 12 times. Found dead in cuffs after being...       1
# 80  @margaretcho Call me a fag and I'm going to ca...       0
# 81  New Nanotech Device Will Be Able To Target And...       0
# 82  @vballplaya2296 want me to send you  some medi...       0
# 83  2 held with heroin in ambulance http://t.co/d9...       0
# 84  http://t.co/B2FaSrt1tN Twelve feared killed in...       1
# 85  Why should a helicopter ambulance ride to tran...       0
# 86  so privileged and proud to wear this uniform.?...       0
# 87  The bartender at work described a drunk man as...       0
# 88  Cop pulls drunk driver to safety SECONDS befor...       1
# 89  Cop pulls drunk driver to safety SECONDS befor...       1
# 90  @RosieGray Now in all sincerety do you think t...       0
# 91  @johnboywest The only 'stage' the drama queen ...       0
# 92  @_drodrolagi #handplacementgoals \nBro we anni...       0
# 93  How do I step outside for 5 seconds and get an...       0
# 94  @jacksfilms #yiayplan well first we strike dre...       0
# 95  'If your nature appropriates it love will burn...       0
# 96  @NinaHoag - 'if you shred my Psych work our fr...       0
# 97  @thehill this is 1 example of y the Conservati...       0
# 98  Aug 3 1915ÛÓKAISERJAEGERS WIPED OUT.; Francis...       0
# 99  They should all die! All of them! Everything a...       0

# %%
# Write output
df_submission = df_test[['id','target']]
